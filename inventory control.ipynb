# %%
import pandas as pd
import matplotlib.pyplot as plt
# Read the CSV file into a pandas DataFrame

df = pd.read_csv("New Inventory.csv",)
df
# Out:
#       Item Number Inventory Receive  Total Item Qty
# 0     064-13-0002          7/7/2023             700
# 1     064-13-0338          7/7/2023            1700
# 2     064-13-0340          7/7/2023            1000
# 3     064-13-0353          7/7/2023            1900
# 4     064-13-0416          7/7/2023            1000
# ...           ...               ...             ...
# 1034  064-09-3787          7/7/2023            2088
# 1035  064-09-5287          7/7/2023            1388
# 1036  064-09-7924          7/7/2023            1632
# 1037  064-09-9076          7/7/2023            1708
# 1038  064-09-9115          7/7/2023            1920
#
# [1039 rows x 3 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1039 entries, 0 to 1038
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Item Number        1039 non-null   object
#  1   Inventory Receive  1039 non-null   object
#  2   Total Item Qty     1039 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 24.5+ KB
# None

# %%
df['Inventory Receive'] = pd.to_datetime(df['Inventory Receive'])

# %%
type(df['Inventory Receive'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['Item Number']=df['Item Number'].str.replace('-','').astype(int)

# %%
df_cleaned = df.pivot_table(index='Item Number', columns='Inventory Receive',dropna=True,fill_value='0')
df_cleaned.head()
# Out:
#                   Total Item Qty                                              \
# Inventory Receive     2023-07-07 2023-07-09 2023-07-10 2023-07-14 2023-07-21
# Item Number
# 64010003                       0          0          0          0          0
# 64010005                       0          0          0          0          0
# 64010012                       0          0          0          0          0
# 64010013                       0          0          0          0          0
# 64010016                       0          0          0          0          0
#
#                                                                           ...  \
# Inventory Receive 2023-07-28 2023-08-04 2023-08-16 2023-08-18 2023-08-22  ...
# Item Number                                                               ...
# 64010003                   0          0          0          0          0  ...
# 64010005                   0          0          0          0          0  ...
# 64010012                   0          0          0          0          0  ...
# 64010013                   0          0          0          0          0  ...
# 64010016                   0          0          0          0          0  ...
#
#                                                                           \
# Inventory Receive 2023-09-22 2023-09-24 2023-09-29 2023-10-08 2023-10-13
# Item Number
# 64010003                   0          0     5488.0          0     1864.0
# 64010005                   0          0     7380.0          0     2520.0
# 64010012                   0          0     6840.0          0     3244.0
# 64010013                   0          0     6300.0          0     1748.0
# 64010016                   0          0     6028.0          0     1608.0
#
#
# Inventory Receive 2023-10-22 2023-11-26 2023-12-01 2023-12-08 2023-12-15
# Item Number
# 64010003                   0          0          0          0          0
# 64010005                   0          0          0          0          0
# 64010012                   0          0          0          0          0
# 64010013                   0          0          0          0          0
# 64010016                   0          0          0          0          0
#
# [5 rows x 23 columns]

# %%
# Assuming 'df' is your DataFrame that you want to save

# Save the entire DataFrame to a CSV file
file_path = 'entire_dataframe.csv'  # Replace 'entire_dataframe.csv' with your desired file path and name
df_cleaned.to_csv(file_path, index=True)  # Set index=False to exclude the DataFrame index from the CSV file

# %%
df_cleaned2 = df.pivot_table(index='Inventory Receive',aggfunc='sum',dropna=True,fill_value='0')
df['Inventory Receive'] = pd.to_datetime(df['Inventory Receive'])
df_cleaned2.head()
# Out:
#                    Item Number  Total Item Qty
# Inventory Receive
# 2023-07-07          3588889892           70284
# 2023-07-09          8204288816          341268
# 2023-07-10          7177751550          166708
# 2023-07-14           128311497            9514
# 2023-07-21           706024390           16336

# %%
# Resample the data to get monthly totals
monthly_totals = df_cleaned2.resample('M').sum()

# Plotting the bar chart for monthly totals

plt.figure(figsize=(10, 6))
monthly_totals.plot(kind='bar', figsize=(8,4))
plt.title('Total Monthly Inventory Levels')
plt.xlabel('Month')
plt.ylabel('Total Inventory')
plt.xticks(rotation=45)
plt.legend(title='Inventory Receive')
plt.tight_layout()
plt.show()
